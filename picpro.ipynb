# %%
import time
import sys

sys.path.append("..")
from MTRT import *
import healpy as hp
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.optimize import curve_fit
from LGSM import LGSM
from datetime import datetime
from DEORtool import DEOR_tool
from DEORtool import EoRmod
from DEORtool import DEOR_simulation
from cbeam import cbeam
from MTRT import Bv
import csv
from IPython.display import Latex

# %%
data1 = []
data2 = []
data3 = []
data4 = []
data5 = []
data6 = []
data7 = []
data8 = []
data1a = []
data1b = []

# %%
csv_reader = csv.reader(open("result1.csv"))
for line in csv_reader:
    data1.append(line)
    
csv_reader = csv.reader(open("result2.csv"))
for line in csv_reader:
    data2.append(line)
    
csv_reader = csv.reader(open("result3.csv"))
for line in csv_reader:
    data3.append(line)
    
csv_reader = csv.reader(open("result4.csv"))
for line in csv_reader:
    data4.append(line)
    
csv_reader = csv.reader(open("result5.csv"))
for line in csv_reader:
    data5.append(line)
    
csv_reader = csv.reader(open("result6.csv"))
for line in csv_reader:
    data6.append(line)
    
csv_reader = csv.reader(open("result7.csv"))
for line in csv_reader:
    data7.append(line)
    
csv_reader = csv.reader(open("result8.csv"))
for line in csv_reader:
    data8.append(line)
    
csv_reader = csv.reader(open("result1a.csv"))
for line in csv_reader:
    data1a.append(line)
    
csv_reader = csv.reader(open("result1b.csv"))
for line in csv_reader:
    data1b.append(line)

# %%
freqs = np.float64(data1[0])
time = np.float64(data1[2])
F1 = np.float64(data1[1])
F2 = np.float64(data2[1])
F3 = np.float64(data3[1])
F4 = np.float64(data4[1])
F5 = np.float64(data5[1])
F6 = np.float64(data6[1])
F7 = np.float64(data7[1])
F8 = np.float64(data8[1])

F1a = np.float64(data1a[1])
F1b = np.float64(data1b[1])

T1 = np.float64(data1[3])
T2 = np.float64(data2[3])
T3 = np.float64(data3[3])
T4 = np.float64(data4[3])
T5 = np.float64(data5[3])
T6 = np.float64(data6[3])
T7 = np.float64(data7[3])
T8 = np.float64(data8[3])

# %%
plt.plot(freqs,F1,label='Meteor Trail E-0')
plt.plot(freqs,F2,label='Meteor Trail E-1')
plt.plot(freqs,F3,label='Meteor Trail E-2')
plt.plot(freqs,F4,label='Meteor Trail E-3')

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

#plt.title("Fixed MT changes the antenna\n temperture vs frequencies",fontsize=24)
plt.ylabel("Antenna received flux/Jy",fontsize=20)
plt.xlabel("Frequencies/MHz",fontsize=20)
plt.legend(prop = {'size':13})
plt.grid()
# plt.savefig("spectrum1",bbox_inches = 'tight',dpi=300)

# %%
plt.plot(freqs,F5,label='Meteor Trail A')
plt.plot(freqs,F6,label='Meteor Trail B')
plt.plot(freqs,F7,label='Meteor Trail C')
plt.plot(freqs,F8,label='Meteor Trail D')

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

#plt.title("Fixed MT changes the antenna\n temperture vs frequencies",fontsize=24)
plt.ylabel("Antenna received flux/Jy",fontsize=20)
plt.xlabel("Frequencies/MHz",fontsize=20)
plt.legend(prop = {'size':13})
plt.grid()
# plt.savefig("spectrum2",bbox_inches = 'tight',dpi=300)

# %%
plt.plot(time,T1,label='Meteor Trail E-0')
plt.plot(time,T2,label='Meteor Trail E-1')
plt.plot(time,T3,label='Meteor Trail E-2')
plt.plot(time,T4,label='Meteor Trail E-3')

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

#plt.title("Fixed MT changes the antenna\n temperture vs frequencies",fontsize=24)
plt.ylabel("Antenna received flux/Jy",fontsize=20)
plt.xlabel("Time/h",fontsize=20)
plt.legend(prop = {'size':13})
plt.grid()
#plt.savefig("spectrum",bbox_inches = 'tight',dpi=300)
# plt.savefig("time1",bbox_inches = 'tight',dpi=300)

# %%
plt.plot(time,T5,label='Meteor Trail A')
plt.plot(time,T6,label='Meteor Trail B')
plt.plot(time,T7,label='Meteor Trail C')
plt.plot(time,T8,label='Meteor Trail D')

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

#plt.title("Fixed MT changes the antenna\n temperture vs frequencies",fontsize=24)
plt.ylabel("Antenna received flux/Jy",fontsize=20)
plt.xlabel("Time/h",fontsize=20)
plt.legend(prop = {'size':13})
plt.grid()
#plt.savefig("spectrum",bbox_inches = 'tight',dpi=300)
# plt.savefig("time2",bbox_inches = 'tight',dpi=300)

# %%
def powerlaw(x,a,b):
    return a*x**b

# %%
popt,pcov = curve_fit(powerlaw,freqs,F1)
plt.plot(freqs,F1)
plt.plot(freqs,powerlaw(freqs,popt[0],popt[1]))
print(popt)
# Out:
# [ 2.53214564e+05 -1.30175562e+00]

# %%
popt,pcov = curve_fit(powerlaw,freqs,F2)
plt.plot(freqs,F2)
plt.plot(freqs,powerlaw(freqs,popt[0],popt[1]))
print(popt)
# Out:
# [ 1.78967231e+05 -1.28861793e+00]

# %%
popt,pcov = curve_fit(powerlaw,freqs,F3)
plt.plot(freqs,F3)
plt.plot(freqs,powerlaw(freqs,popt[0],popt[1]))
print(popt)
# Out:
# [ 1.26130074e+05 -1.33645696e+00]

# %%
popt,pcov = curve_fit(powerlaw,freqs,F4)
plt.plot(freqs,F4)
plt.plot(freqs,powerlaw(freqs,popt[0],popt[1]))
print(popt)
# Out:
# [ 3.42005160e+05 -1.30621958e+00]

# %%
popt,pcov = curve_fit(powerlaw,freqs,F5)
plt.plot(freqs,F5)
plt.plot(freqs,powerlaw(freqs,popt[0],popt[1]))
print(popt)
# Out:
# [ 6.49930401e+04 -1.33419401e+00]

# %%
popt,pcov = curve_fit(powerlaw,freqs,F6)
plt.plot(freqs,F6)
plt.plot(freqs,powerlaw(freqs,popt[0],popt[1]))
print(popt)
# Out:
# [ 9.65916458e+04 -1.34080504e+00]

# %%
popt,pcov = curve_fit(powerlaw,freqs,F7)
plt.plot(freqs,F7)
plt.plot(freqs,powerlaw(freqs,popt[0],popt[1]))
print(popt)
# Out:
# [ 1.51592241e+05 -1.30159440e+00]

# %%
popt,pcov = curve_fit(powerlaw,freqs,F8)
plt.plot(freqs,F8)
plt.plot(freqs,powerlaw(freqs,popt[0],popt[1]))
print(popt)
# Out:
# [ 2.07539723e+05 -1.31992898e+00]

# %%
popt,pcov = curve_fit(powerlaw,freqs,F1a)
plt.plot(freqs,F1a)
plt.plot(freqs,powerlaw(freqs,popt[0],popt[1]))
print(popt)
# Out:
# [ 2.53246034e+04 -1.30177677e+00]

# %%
popt,pcov = curve_fit(powerlaw,freqs,F1b)
plt.plot(freqs,F1b)
plt.plot(freqs,powerlaw(freqs,popt[0],popt[1]))
print(popt)
# Out:
# [ 2.53249197e+03 -1.30177890e+00]

# %%
plt.plot(freqs,np.log(F1),label='$q=10^{18}e/m$')
plt.plot(freqs,np.log(F1a),label='$q=10^{16}e/m$')
plt.plot(freqs,np.log(F1b),label='$q=10^{14}e/m$')

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

#plt.title("Fixed MT changes the antenna\n temperture vs frequencies",fontsize=24)
plt.ylabel("Antenna received flux/log(Jy)",fontsize=20)
plt.xlabel("Frequencies/MHz",fontsize=20)
plt.legend(prop = {'size':13})
plt.grid()
#plt.savefig("eld",bbox_inches = 'tight',dpi=300)

# %%
(1.334+1.331+1.302+1.320+1.302+1.289+1.336+1.306)/8
# Out:
# 1.315
